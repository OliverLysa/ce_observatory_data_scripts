# %%
# Import libraries from which to call functions e.g. urllib 
import urllib.request
import traceback
import pandas as pd  # library for data analysis
import requests  # library to handle requests
from bs4 import BeautifulSoup  # library to parse HTML documents
import pyproj
import traceback
from lat_lon_parser import parse
import geopy.distance

# %%
# Get the response in the form of html by calling the URL
wikiurl = "https://en.wikipedia.org/wiki/List_of_onshore_wind_farms_in_the_United_Kingdom"
table_class = "wikitable sortable jquery-tablesorter"
response = requests.get(wikiurl)
# print response status from call. If 200, then there is success in retrieval of data
print(response.status_code)

# Parse data table from the html into a beautifulsoup object
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table', {'class': "wikitable"})[3]
df = pd.read_html(str(table))
# Convert that list object to a dataframe
Wales = pd.DataFrame(df[0])
# Out:
# 200
# /var/folders/vc/gszmszx94qn2yq038bgz88mr0000gn/T/ipykernel_75718/1470382607.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))

# %%
# Out:
# [                           Wind farm              County  \
# 0                          Llyn Alaw            Anglesey
# 1     Alltwalis (formerly Blaengwen)     Carmarthenshire
# 2                         Blaen Bowi     Carmarthenshire
# 3                         Parc Cynog     Carmarthenshire
# 4   Pendine (Parc Cynog Extension I)     Carmarthenshire
# 5                         Cefn Croes          Ceredigion
# 6                     Dyffryn Brodyn          Ceredigion
# 7                       Llangwyryfon          Ceredigion
# 8                      Mynydd Gorddu          Ceredigion
# 9                            Rheidol          Ceredigion
# 10                      Rhyd-y-Groes            Anglesey
# 11                     Moel Maelogen               Conwy
# 12           Moel Maelogen Extension               Conwy
# 13            Tir Mostyn & Foel Goch        Denbighshire
# 14             Wern Ddu (Craig Lelo)        Denbighshire
# 15                   Braich Ddu Farm             Gwynedd
# 16           Hafoty Ucha 2 Extension             Gwynedd
# 17                         Trysglwyn            Anglesey
# 18                       Ffynnon Oer   Neath Port Talbot
# 19       Castle Pill Farm Repowering       Pembrokeshire
# 20                    Solutia UK Ltd       Pembrokeshire
# 21                        Bryn Titli               Powys
# 22                   Carno ’A’ & ’B’               Powys
# 23                   Carno Extension               Powys
# 24                           Cemmaes               Powys
# 25                     Llandinam P&L               Powys
# 26                     Mynydd Clogau               Powys
# 27                          Taff Ely  Rhondda Cynon Taff
#
#                                        Coordinates                Model  \
# 0   53°21′48″N 04°26′59″W﻿ / ﻿53.36333°N 4.44972°W           Bonus B600
# 1   51°58′42″N 04°15′03″W﻿ / ﻿51.97833°N 4.25083°W      Siemens SWT-2.3
# 2   51°59′17″N 04°26′43″W﻿ / ﻿51.98806°N 4.44528°W           Nordex N60
# 3   51°45′33″N 04°32′40″W﻿ / ﻿51.75917°N 4.54444°W            NEG Micon
# 4   51°45′33″N 04°32′40″W﻿ / ﻿51.75917°N 4.54444°W          Enercon E48
# 5   52°24′18″N 03°45′03″W﻿ / ﻿52.40500°N 3.75083°W             GE 1.5se
# 6   51°52′09″N 04°33′25″W﻿ / ﻿51.86917°N 4.55694°W      Nordtank NTK500
# 7   52°18′26″N 04°01′43″W﻿ / ﻿52.30722°N 4.02861°W           Vestas V52
# 26                    0.85   17      14.45    2006
# 27                    0.45   20       9.00    1993
#
#                       Developer                Operator  \
# 0             npower renewables                  Innogy
# 1         Statkraft Wind UK Ltd                       -
# 2             Windjen Power Ltd       Windjen Power Ltd
# 3               Nuon Renewables         Nuon Renewables
# 4               Nuon Renewables         Nuon Renewables
# 5              Falck Renewables  RDC / Falck Renewables
# 6               New World Power                     RES
# 7   First Windfarm Holdings Ltd      Cumbria Wind Farms
# 8                         Amgen                  Innogy
# 9            E.ON UK Renewables                     RES
# 10           E.ON UK Renewables               B9 Energy
# 11          Cwmni Gwynt Teg Cyf                  GT O+M
# 12                 Ail Wynt Cyf                       -
# 13            Windjen Power Ltd                       -
# 14                        Tegni                       -
# 15                REG Windpower                       -
# 16                        Tegni                   Tegni
# 17            npower renewables                  Innogy
# 18            npower renewables                  Innogy
# 19                    Infinergy                       -
# 20                  Wind Direct                       -
# 21            npower renewables                  Innogy
# 22            npower renewables                  Innogy
# 23                       Amegni                       -
# 24  First Windfarm Holdings Ltd      Cumbria Wind Farms
# 25  Scottish Power/Eurus Energy                     SKM
# 26                       Novera                     SKM
# 27                 Perma Energy                  Innogy
#
#                           Owner       Website
# 0         Beaufort Wind Limited         [137]
# 1                             -         [138]
# 2             Windjen Power Ltd           NaN
# 3               Nuon Renewables         [139]
# 4               Nuon Renewables         [140]
# 5              Falck Renewables         [141]
# 6                           RES         [142]
# 7      First Wind Farm Holdings         [143]
# 8         Beaufort Wind Limited         [144]
# 9               E.ON Renewables  [145]; [146]
# 10              E.ON Renewables         [147]
# 11          Cwmni Gwynt Teg Cyf         [148]
# 12                            -         [149]
# 13                    HgCapital         [150]
# 14                            -         [151]
# 15                            -         [152]
# 16                        Tegni         [153]
# 17        Beaufort Wind Limited         [154]
# 18                       Innogy         [155]
# 19                            -         [156]
# 20              Wind Direct Ltd         [157]
# 21        Beaufort Wind Limited         [158]
# 22        Beaufort Wind Limited         [159]
# 23                            -         [160]
# 24     First Wind Farm Holdings         [161]
# 25  Scottish Power/Eurus Energy         [162]
# 26            Novera Energy plc         [163]
# 27        Beaufort Wind Limited         [164]  ]

# %%
Total_onshore = pd.concat([England, Wales, Ireland, Scotland], axis=0)

# Filter to operational in the development status column
filter_list_status = ['[1]']
Total_onshore = Total_onshore[~Total_onshore.Website.isin(filter_list_status)]

# Keep wanted columns in the dataframe
Total_onshore = Total_onshore[['Wind farm', 'Model', 'Owner', 'Coordinates']]
Total_onshore = Total_onshore.rename(columns={'Wind farm': 'Name'})

# Remove leading and trailing spaces in name column to make it easier to match across data tables 
Total_onshore['Name'] = Total_onshore['Name'].str.strip()

Total_onshore['Coordinates'] = Total_onshore['Coordinates'].replace(r"\(.*/)", "")

Total_onshore

Total_onshore.to_csv('Total_onshore.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Total_onshore = pd.concat([England, Wales, Ireland, Scotland], axis=0)
#       3 # Filter to operational in the development status column
#       4 filter_list_status = ['[1]']
#
# NameError: name 'England' is not defined
